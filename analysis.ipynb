# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./datasets/combined_data_set2.csv', index_col = 0)
random_dataset2 = df.values
df.head()
# Out:
#                             Lamp_State  Fan_State  Bathroom_Humidity  \
# Date/Time
# 2019-07-11-11:04:09.853149           1          1               73.0
# 2019-07-11-11:05:13.646322           1          1               68.0
# 2019-07-11-11:06:22.516171           1          1               67.0
# 2019-07-11-11:07:26.347397           1          1               68.0
# 2019-07-11-11:08:35.230643           1          1               68.0
#
#                             Bathroom_Temperature  Bedroom1_Humidity  \
# Date/Time
# 2019-07-11-11:04:09.853149                  69.8               67.0
# 2019-07-11-11:05:13.646322                  75.2               66.0
# 2019-07-11-11:06:22.516171                  75.2               61.0
# 2019-07-11-11:07:26.347397                  75.2               55.0
# 2019-07-11-11:08:35.230643                  75.2               46.0
#
#                             Bedroom1_Temperature  Kitchen_Humidity  \
# Date/Time
# ...

# %%
plt.figure()
df.Bathroom_Temperature.plot()
df.Bedroom1_Temperature.plot()
df.Bedroom2_Temperature.plot()
df.Kitchen_Temperature.plot()
df.Diningroom_Temperature.plot()
df.Livingroom1_Temperature.plot()

# %%
plt.figure()
df.Bathroom_Humidity.plot()
df.Bedroom1_Humidity.plot()
df.Bedroom2_Humidity.plot()
df.Kitchen_Humidity.plot()
df.Diningroom_Humidity.plot()
df.Livingroom1_Humidity.plot()
